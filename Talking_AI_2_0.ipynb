# %% [markdown]
# <a href="https://colab.research.google.com/github/PIYUSH9760/python_classes/blob/main/Talking_AI_2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
import time

class User:
    def __init__(self, name):
        self.name = name.upper()

class Assistant(object):
    def __init__(self, user):
        self.user = user

    def greet(self):
        print('Press start to talk')
        x = input()
        if x.lower() in ('start', 'START'):
            print('GOOD MORNING MASTER')
            print('''I am VEGAPUNK1 - My creater is Piyush Nautiyal. He is a student pursuing
                       his BTech from Petroleum University. He belongs to mussoorie ''')
            print("===========")
            print("|         |")
            print("| O     O |")
            print("|    '    |")
            print("| ******* |")
            print("|         |")
            print("===========")
            print()

    def get_option(self):
        print('Hello', self.user.name, ',')
        print('')
        print('HOW CAN I HELP YOU ?')
        print('')
        print('Press 1 - Then we will start talking about your day', self.user.name)
        print('')
        print('Press 2 - To play a game and make your time fun', self.user.name)
        print('')
        print('Press 3 - To play number guessing game ', self.user.name)
        print('')
        print('Press 4 - Then we will talk about you', self.user.name)
        print('')
        print('Press 5 - To claculate your class 10th percentage with PCM percentage',  self.user.name)
        print('')
        return int(input())

    def handle_option(self, option):
        if option == 1:
            self.talk_about_day()
        elif option == 2:
            self.play_dice_game()
        elif option == 3:
            self.number_guessing_game()
        elif option == 4:
            self.talk_about_user()
        elif option == 5:
            self.calculate_percentages()
        else:
            print("Invalid option. Please choose from 1, 2,3 or 4.")

    def talk_about_day(self):
        print('How was your day', self.user.name, 'Good or Bad ?')
        print('')
        z = input()
        print('')
        if(z=='bad'):
          print('Dont worry take rest and watch your favorite drama',name,' or you can play games ')
        else:
          print('It is really good to hear that your day was' ,z,name,' and i hope that all of your time goes enthusiastic and fun',name)
        print('')
        print('At what time do you wake up in the morning',name,'?')
        print('')
        t=int(input())
        print('')
        if(t<7):
          print('it is really nice , only 35% of world population wakes up at this time')
        else:
          print('you should sleep early and wake up at 5 , bad boy',name)
        print('')
        print('Did you learn something new today',name)
        print('')
        i=input()
        print('')
        if(i == 'yes'):
          print('Really impressive you should always learn something new,  Good Going',name)
        else:
          print('You should start improving you habits and learn something new per day',name)

    def play_dice_game(self):
        print("This is a dice stimulator")
        x = "y"
        while x == "y":
            number = random.randint(1, 6)

            if number == 1:
                print("===========")
                print("|         |")
                print("|    O    |")
                print("|         |")
                print("===========")

            if number == 2:
                print("===========")
                print("|         |")
                print("| O     O |")
                print("|         |")
                print("===========")

            if number == 3:
                print("===========")
                print("|    O    |")
                print("|    O    |")
                print("|    O    |")
                print("===========")

            if number == 4:
                print("===========")
                print("| O     O |")
                print("|         |")
                print("| O     O |")
                print("===========")

            if number == 5:
                print("===========")
                print("| O     O |")
                print("|    O    |")
                print("| O     O |")
                print("===========")

            if number == 6:
                print("===========")
                print("| O     O |")
                print("| O     O |")
                print("| O     O |")
                print("===========")

            x =  input("Press y to roll again ")

    def number_guessing_game(self):
      print('Let start the game ')
      time.sleep(2)
      n = random.randint(1, 10)
      print('Number has been generated!!\nYou have 4 chances to guess the number')

      count = 4

      while count!=0:
        a = int(input('Guess the number: '))

        if (a == n):
            print("Yay! That's right. You won!")
            break
        elif a > n:
           print('The number is less than ', a)
        else:
           print('The number is greater than ', a)
        count=-1

      def talk_about_user(self):
        print('What is your goal or ambition', self.user.name, '?')
        k = input()
        print('That is really great',name,'you have really nice goal to achieve work hard nd stay consistent')
        print('')
        print('What are your Hobbies',name,'?')
        l=input()
        print('impressive',name)
        print('')
        print('What do you like to do in you free time ?')
        e=input()
        print('''That is some good choice but you should also form a habit
        to learn and read book, Play Sports and try improving your qualities''')


    def calculate_percentages(self):
          """
          This function takes user input for class 10 marks, calculates overall and PCM percentages, assigns grades, provides remarks, and creates a DataFrame with user information.
          """


          user_name = input("Enter your name: ")

          subjects = ["English", "Hindi", "Mathematics", "Physics", "Social Science", "Chemistry", "Biology"]
          max_marks = [100, 100, 100, 100, 100, 100, 100]

          marks = []
          for subject in subjects:
            while True:
              try:
                mark = int(input(f"Enter marks for {subject}: "))
                if 0 <= mark <= max_marks[subjects.index(subject)]:
                  marks.append(mark)
                  break
                else:
                  print(f"Invalid marks entered for {subject}. Please enter a value between 0 and {max_marks[subjects.index(subject)]}.")
              except ValueError:
                print("Invalid input. Please enter a numeric value.")

          total_marks = sum(marks)
          overall_percentage = (total_marks / sum(max_marks)) * 100



          failed_subjects = [subject for i, subject in enumerate(subjects) if marks[i] < 50]

          pcm_subjects = ["Physics", "Chemistry", "Mathematics"]
          pcm_indices = [subjects.index(subject) for subject in pcm_subjects if subject in subjects]

          if len(pcm_indices) != len(pcm_subjects):
            print("Warning: Not all PCM subjects found in marks list.")
          else:
            pcm_marks = [marks[i] for i in pcm_indices]
            pcm_percentage = (sum(pcm_marks) / (len(pcm_subjects) * 100)) * 100


          data = {
              "Name": user_name,
              "Subjects": subjects,
              "Marks": marks,
              "Pass/Fail": ["Pass" if mark >= 50 else "Fail" for mark in marks],
          }

          df = pd.DataFrame(data)


          print("\nResults Summary:")
          print(df.to_string(index=False))

          if failed_subjects:
            print(f"\nFailed Subjects: {', '.join(failed_subjects)}")

          print(f"\nOverall Percentage: {overall_percentage:.2f}%")


    def run(self):
        self.greet()
        option = self.get_option()
        self.handle_option(option)
        print('')
        print('Thank you,', self.user.name, 'for using VEGAPUNK1')

if __name__ == "__main__":
    name = input("Enter your name: ")
    user = User(name)
    assistant = Assistant(user)
    assistant.run()
