# %% [markdown]
# <a href="https://colab.research.google.com/github/PIYUSH9760/python_classes/blob/main/Python_project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
print('Press start to talk')
x=input()
if(x=='start' or 'Start' or 'START'):
  print('GOOD MORNING MASTER')
  print('''I am VEGAPUNK1 - My creater is Piyush Nautiyal. He is a student pursuing
              his BTech from Petroleum University. He belongs to mussoorie ''')
  print("===========")
  print("|         |")
  print("| O     O |")
  print("|    '    |")
  print("| ******* |")
  print("|         |")
  print("===========")
  print()
  name=input('Enter your name ')
  name=name.upper()
  print('Hello',name,)
  print('')
  print('How can i help you ?')
  print('')
  print('Press 1  - Then we will start talking about your day',name)
  print('')
  print('Press 2 - To play a game and make your time fun',name)
  print('')
  print('Press 3 - Then we will talk about you',name)
  print('')
  y=int(input())
  if(y==1):
    print('How was your day',name,'Good or Bad ?')
    z=input()
    if(z=='Bad'):
      print('Dont worry take rest and watch your favorite drama',name,' or you can play games ')
    else:
      print('It is really good to hear that your day was' ,z,name,' and i hope that all of your time goes enthusiastic and fun',name)
      print('')
    print('At what time do you wake up in the morning',name,'?')
    t=int(input())
    if(t<7):
      print('it is really nice , only 35% of world population wakes up at this time')
    else:
      print('you should sleep early and wake up at 5 , bad boy',name)
    print('')
    print('Did you learn something new today',name)
    i=input()
    if(i == 'yes'):
      print('Really impressive you should always learn something new good going',name)
    else:
      print('You should start improving you habits',name)

  elif(y==2):
    print("This is a dice stimulator")
    x = "y"
    while x == "y":
        number = random.randint(1,6)

        if number == 1:
            print("===========")
            print("|         |")
            print("|    O    |")
            print("|         |")
            print("===========")

        if number == 2:
            print("===========")
            print("|         |")
            print("| O     O |")
            print("|         |")
            print("===========")

        if number == 3:
            print("===========")
            print("|    O    |")
            print("|    O    |")
            print("|    O    |")
            print("===========")

        if number == 4:
            print("===========")
            print("| O     O |")
            print("|         |")
            print("| O     O |")
            print("===========")

        if number == 5:
            print("===========")
            print("| O     O |")
            print("|    O    |")
            print("| O     O |")
            print("===========")

        if number == 6:
            print("===========")
            print("| O     O |")
            print("| O     O |")
            print("| O     O |")
            print("===========")

        x =  input("Press y to roll again ")

  if(y==3):
    print('What is your goal or ambition',name,'?')
    k=input()
    print('That is really great',name,'you have really nice goal to achieve work hard nd stay consistent')
    print('')
    print('What are your Hobbies',name,'?')
    l=input()
    print('impressive',name)
    print('')
    print('What do you like to do in you free time ?')
    e=input()
    print('''That is some good choice but you should also form a habit
    to learn and read book, Play Sports and try improving your qualities''')

  print('')
  print('')
  print('Thank you',name,'for using VEGAPUNK')
# Out:
# Press start to talk
# start
# GOOD MORNING MASTER
# I am VEGAPUNK1 - My creater is Piyush Nautiyal. He is a student pursuing
#               his BTech from Petroleum University. He belongs to mussoorie
# ...
# |         |
# | O     O |
# |    '    |
# | ******* |
# |         |
# ...
#
# Enter your name piyush
# Hello PIYUSH
#
# How can i help you ?
#
# Press 1  - Then we will start talking about your day PIYUSH
#
# Press 2 - To play a game and make your time fun PIYUSH
#
# Press 3 - Then we will talk about you PIYUSH
#
# 2
# This is a dice stimulator
# ...
# |         |
# |    O    |
# |         |
# ...
# Press y to roll again y
# ...
# |         |
# | O     O |
# |         |
# ...
# Press y to roll again y
# ...
# |         |
# |    O    |
# |         |
# ...
# Press y to roll again h
#
#
# Thank you PIYUSH for using VEGAPUNK
